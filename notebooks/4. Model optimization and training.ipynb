# %% [markdown]
# #### Clone repo and pull data from DVC

# %%
# !git clone https://dagshub.com/gianfrancodemarco/plate-recognition.git
# Out:
# Cloning into 'plate-recognition'...
# remote: Enumerating objects: 1603, done.
# remote: Counting objects: 100% (1603/1603), done.
# remote: Compressing objects: 100% (945/945), done.
# remote: Total 1603 (delta 873), reused 921 (delta 496), pack-reused 0
# Receiving objects: 100% (1603/1603), 20.03 MiB | 7.66 MiB/s, done.
# Resolving deltas: 100% (873/873), done.

# %%
import os
os.chdir('plate-recognition')
# !pip install dvc
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.0/407.0 KB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 KB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 29.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 KB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 KB 6.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.6/405.6 KB 46.0 MB/s eta 0:00:00
# ...

# %%
cat .env

# %% [markdown]
# Parameters Optimizations

# %%
# !dvc repro -s download_data
# !dvc repro -s make_dataset
#!python src/models/hyperparameters_tuning.py
# Out:
# Running stage 'download_data':
# > python src/pipeline/download_data.py
# 2023-01-26 21:23:37,652 - root - INFO - Loaded environment variables
# Traceback (most recent call last):
#   File "src/pipeline/download_data.py", line 6, in <module>
#     from src.data.misc import fetch_or_resume
#   File "/content/plate-recognition/src/data/__init__.py", line 1, in <module>
#     from . import image_preprocessing
#   File "/content/plate-recognition/src/data/image_preprocessing.py", line 1, in <module>
#     import albumentations as A
#   File "/usr/local/lib/python3.8/dist-packages/albumentations/__init__.py", line 5, in <module>
#     from .augmentations import *
#   File "/usr/local/lib/python3.8/dist-packages/albumentations/augmentations/__init__.py", line 6, in <module>
#     from .domain_adaptation import *
#   File "/usr/local/lib/python3.8/dist-packages/albumentations/augmentations/domain_adaptation.py", line 6, in <module>
#     from qudida import DomainAdapter
# ...

# %%
# !dvc repro -s download_data
# !dvc repro -s make_dataset
# !dvc repro -f -s train_model
# Out:
# Running stage 'download_data':
# > python src/pipeline/download_data.py
# 2023-01-26 21:24:13,971 - root - INFO - Loaded environment variables
# 2023-01-26 21:24:15,469 - root - INFO - Downloading dataset...
# 2023-01-26 21:24:15,469 - root - INFO - Downloading https://drive.google.com/uc?id=1bTxEOmOtIzHPV8N43ZnJTyVu7lonIP1o&export=download in /content/plate-recognition/data/raw/plate-recognition-dataset.zip
# 2023-01-26 21:24:15,472 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): drive.google.com:443
# 2023-01-26 21:24:18,817 - urllib3.connectionpool - DEBUG - https://drive.google.com:443 "GET /uc?id=1bTxEOmOtIzHPV8N43ZnJTyVu7lonIP1o&export=download HTTP/1.1" 303 0
# 2023-01-26 21:24:18,819 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): doc-04-8c-docs.googleusercontent.com:443
# ...

# %%
# !dvc repro -f -s test_model
